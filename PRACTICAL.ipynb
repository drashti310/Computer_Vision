# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **2. Implement the basic operations on images using OpenCV.**
#
#
# *1. Read an image*

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2
img=cv2.imread('/content/drive/My Drive/cv/1.jpeg')
plt.imshow(img)
plt.show()
#img2=cv2.imread()
#cv2_imshow(img)

# %%
import numpy as np
import cv2 
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
img=cv2.imread('/content/drive/My Drive/cv/1.jpeg')
img1=cv2.imread('/content/drive/My Drive/cv/10.jpeg')
cv2_imshow(img)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F9704B00550>
# <PIL.Image.Image image mode=RGB size=265x190 at 0x7F9704B00630>

# %%
import cv2
img = cv2.imread("/content/drive/My Drive/cv/1.jpeg")
newImg = cv2.resize(img, (0,0), fx=0.75, fy=0.75)
cv2.imshow(newImg)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-10-c8fd1ab6ed7b> in <module>()
#       2 img = cv2.imread("/content/drive/My Drive/cv/1.jpeg")
#       3 newImg = cv2.resize(img, (0,0), fx=0.75, fy=0.75)
# ----> 4 cv2.imshow(newImg)
#       5 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
import cv2
img = cv2.imread("/content/drive/My Drive/cv/2.jpeg")
newImg = cv2.resize(img, (0,0), fx=0.75, fy=0.75)
cv2_imshow(newImg)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=199x142 at 0x7F69BEFE2358>
# -1

# %%
#Write an image
img = cv2.imread("/content/drive/My Drive/cv/10.jpeg")
cv2.imwrite("/content/drive/My Drive/cv/savedImage.jpeg", img)
# Out:
# True

# %%
#Access pixel values and modify them
import cv2
image = cv2.imread("/content/drive/My Drive/cv/images.jpg")
pixel= image[100, 100]
print(pixel)
# Out:
# [255 255 221]

# %%
img[100,100] = [255,255,255]
print( img[100,100] )
# Out:
# [255 255 255]

# %%
import cv2
import numpy as np
img_file = '/content/drive/My Drive/cv/images.jpg'
img = cv2.imread(img_file, cv2.IMREAD_COLOR)           # rgb
alpha_img = cv2.imread(img_file, cv2.IMREAD_UNCHANGED) # rgba
gray_img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)  # grayscale

cv2.imshow(img_file)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-2-a3d18d85a0fd> in <module>()
#       6 gray_img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)  # grayscale
#       7
# ----> 8 cv2.imshow(img_file)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
import cv2
img = cv2.imread('/content/drive/My Drive/cv/images.jpg')

r = cv2.selectROI("Image", img, False, False)

cv2.imshow(r)

# %%
import cv2
img = cv2.imread('/content/drive/My Drive/cv/9.jpeg')
color = [181, 58, 170]
top, bottom, left, right = [50]*4
img_border = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
cv2.imshow(img_border)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-1-a7cec5fc238f> in <module>()
#       4 top, bottom, left, right = [50]*4
#       5 img_border = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
# ----> 6 cv2.imshow(img_border)
#       7 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
import cv2
from matplotlib import pyplot as plt
img=cv2.imread('/content/drive/My Drive/cv/22.jpg')
print(img.shape)
b,g,r=cv2.split(img)
Dog=cv2.merge((b,g,r))
plt.subplot(1,5,1),plt.imshow(img)
plt.title('image 5')
# Out:
# (227, 222, 3)
# Text(0.5, 1.0, 'image 5')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
BLUE = [100,100,0]
img1 = cv2.imread('/content/drive/My Drive/cv/11.jpg')
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %%
import cv2

img1 = cv2.imread("/content/drive/My Drive/cv/7.jpeg")
img1.resize(200,200,3)
img2 = cv2.imread("/content/drive/My Drive/cv/8.jpeg")
img2.resize(200,200,3)

img = cv2.add(img1,img2)

plt.subplot(1,5,1),plt.imshow(img1)
plt.title('image 1 ')
plt.subplot(1,5,2),plt.imshow(img2)
plt.title('image 2 ')
plt.subplot(1,5,3),plt.imshow(img)
plt.title(' OUTPUT ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-865581407f8f> in <module>()
#       2
#       3 img1 = cv2.imread("/content/drive/My Drive/cv/7.jpeg")
# ----> 4 img1.resize(200,200,3)
#       5 img2 = cv2.imread("/content/drive/My Drive/cv/8.jpeg")
#       6 img2.resize(200,200,3)
#
# AttributeError: 'NoneType' object has no attribute 'resize'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img1 = cv2.imread("/content/drive/My Drive/cv/1.jpg")
img1.resize(500,500,3)
img2 = cv2.imread("/content/drive/My Drive/cv/2.jpg")
img2.resize(500,500,3)
img = cv2.addWeighted(img1, 0.3, img2, 0.7, 0)
plt.subplot(1,5,1),plt.imshow(img1)
plt.title('image 1 ')
plt.subplot(1,5,2),plt.imshow(img2)
plt.title('image 2 ')
plt.subplot(1,5,3),plt.imshow(img)
plt.title(' OUTPUT ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-23bd96119260> in <module>()
#       3 from matplotlib import pyplot as plt
#       4 img1 = cv2.imread("/content/drive/My Drive/cv/1.jpg")
# ----> 5 img1.resize(500,500,3)
#       6 img2 = cv2.imread("/content/drive/My Drive/cv/2.jpg")
#       7 img2.resize(500,500,3)
#
# AttributeError: 'NoneType' object has no attribute 'resize'
