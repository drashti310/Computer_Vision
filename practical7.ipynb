# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#erosion
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(erosion),plt.title('Erosion')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
#dilation
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
erosion = cv.dilate(img,kernel,iterations = 1)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(erosion),plt.title('Dilation')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
#opening
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(opening),plt.title('Opening')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
#opening
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(closing),plt.title('closing')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gradient),plt.title('gradient')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
#filling
import cv2 as cv
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png")
kernel = np.ones((5,5),np.uint8)
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt. xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gradient),plt.title('Filling')
plt.xticks([]), plt.yticks ([])
plt.show()

# %%
import cv2 
import numpy as np
img = cv2.imread("/content/drive/My Drive/cv/j.png") 
kernel = np.ones((5,5),np.uint8) 
thick = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
cv2.imshow("Image",img)
cv2.imshow("Thicking Image",thick)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-1bc507bb0ca0> in <module>()
#       3 img = cv2.imread("/content/drive/My Drive/cv/j.png")
#       4 kernel = np.ones((5,5),np.uint8)
# ----> 5 thick = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
#       6 cv2.imshow("Image",img)
#       7 cv2.imshow("Thicking Image",thick)
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'

# %%
import cv2 
import numpy as np
img = cv2.imread('C:/Users/margi/Desktop/3.jpg',0) 
kernel = np.ones((5,5),np.uint8) 
thick = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
cv2.imshow("Image",img)
cv2.imshow("Thicking Image",thick)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-50dfcb64bdeb> in <module>()
#       3 img = cv2.imread('C:/Users/margi/Desktop/3.jpg',0)
#       4 kernel = np.ones((5,5),np.uint8)
# ----> 5 thick = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
#       6 cv2.imshow("Image",img)
#       7 cv2.imshow("Thicking Image",thick)
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'
