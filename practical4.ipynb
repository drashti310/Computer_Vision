# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#4. Perform following operations on histogram
#● Generate histogram and perform histogram equalization of an image

import cv2 
from matplotlib import pyplot as plt 
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

img = cv2.imread("/content/drive/My Drive/cv/1.jpeg")

# alternative way to find histogram of an image 
plt.hist(img.ravel(),256,[0,256]) 
plt.show()

# %%
#histogram equalization of an image
from matplotlib import pyplot as plt 
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

img = cv2.imread("/content/drive/My Drive/cv/1.jpeg")
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img1)
equ = cv2.equalizeHist(img1)
res = np.hstack((img1,equ)) #stacking images side-by-side
cv2_imshow(equ)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F7EEFFD62E8>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F7EEFFD62B0>

# %%
img = cv2.imread("/content/drive/My Drive/cv/images.jpg")
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread("/content/drive/My Drive/cv/3.jpeg",0)
# create a mask
mask = np.zeros(img.shape[:2], np.uint8)
mask[100:300, 100:400] = 255
masked_img = cv2.bitwise_and(img,img,mask = mask)
# Calculate histogram with mask and without mask
# Check third argument for mask
hist_full = cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img],[0],mask,[256],[0,256])
plt.subplot(221), plt.imshow(img, 'gray')
plt.title('original')
plt.subplot(222), plt.imshow(mask,'gray')
plt.title('\n mask')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.title('\n\n masked image')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.title('\n\n histogram')
plt.xlim([0,256])
plt.show()
